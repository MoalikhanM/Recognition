# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread('images/happy_boy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\aoral\.deepface\weights\facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 7.53MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\aoral\.deepface\weights\age_model_weights.h5
# 100%|██████████| 539M/539M [01:22<00:00, 6.50MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\aoral\.deepface\weights\gender_model_weights.h5
# 100%|██████████| 537M/537M [01:06<00:00, 8.05MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# ...

# %%
predictions
# Out:
# {'emotion': {'angry': 4.194861585152162e-14,
#   'disgust': 9.53636575711282e-19,
#   'fear': 7.283825307666085e-14,
#   'happy': 100.0,
#   'sad': 7.319681292290367e-12,
#   'surprise': 1.2050488712900438e-12,
#   'neutral': 2.0170404013697407e-06},
#  'dominant_emotion': 'happy',
#  'region': {'x': 320, 'y': 293, 'w': 662, 'h': 662},
#  'age': 20,
#  'gender': 'Man',
#  'race': {'asian': 0.06317821680568159,
#   'indian': 0.42793205939233303,
#   'black': 0.014695462596137077,
#   'white': 61.50907874107361,
#   'middle eastern': 21.44344300031662,
#   'latino hispanic': 16.541674733161926},
#  'dominant_race': 'white'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(gray,1.1,4)

for(x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
               predictions['dominant_emotion'],
               (0,50),
               font, 1,
               (0, 0, 255),
               2,
               cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
################################################################################################################################

# %%
img_two = cv2.imread('images/sad_woman.png')
plt.imshow(img_two)

# %%
plt.imshow(cv2.cvtColor(img_two, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img_two)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:17<00:00,  4.32s/it]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.4856793499397844,
#   'disgust': 0.0004461309156228123,
#   'fear': 0.34788911907459014,
#   'happy': 4.601475599485916e-05,
#   'sad': 98.99665707329852,
#   'surprise': 8.127154189988848e-06,
#   'neutral': 0.16927561800334562},
#  'dominant_emotion': 'sad',
#  'region': {'x': 47, 'y': 11, 'w': 103, 'h': 103},
#  'age': 31,
#  'gender': 'Woman',
#  'race': {'asian': 99.0838348865509,
#   'indian': 0.2135033719241619,
#   'black': 0.001142271503340453,
#   'white': 0.13070206623524427,
#   'middle eastern': 0.0004861223260377301,
#   'latino hispanic': 0.5703316535800695},
#  'dominant_race': 'asian'}

# %%
predictions['dominant_emotion']
# Out:
# 'sad'

# %%
gray = cv2.cvtColor(img_two, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(gray,1.1,4)

for(x, y, w, h) in faces:
    cv2.rectangle(img_two, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img_two, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img_two,
               predictions['dominant_emotion'],
               (0,50),
               font, 1,
               (0, 0, 255),
               2,
               cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img_two, cv2.COLOR_BGR2RGB))

# %%
################################################################################################################################

# %%
img_test= cv2.imread('images/test.jpg')
plt.imshow(img_test)

# %%
plt.imshow(cv2.cvtColor(img_test, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img_test)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:11<00:00,  3.00s/it]

# %%
predictions
# Out:
# {'emotion': {'angry': 1.7704939469695091,
#   'disgust': 5.21990140001094e-07,
#   'fear': 12.255735695362091,
#   'happy': 0.02720426127780229,
#   'sad': 1.5270348638296127,
#   'surprise': 0.8460008539259434,
#   'neutral': 83.57353210449219},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 103, 'y': 96, 'w': 260, 'h': 260},
#  'age': 23,
#  'gender': 'Man',
#  'race': {'asian': 99.39068552200112,
#   'indian': 0.16550647382849298,
#   'black': 0.007947728336932709,
#   'white': 0.030994507352494143,
#   'middle eastern': 0.00010390910511867979,
#   'latino hispanic': 0.40476841470708935},
#  'dominant_race': 'asian'}

# %%
predictions['dominant_emotion']
# Out:
# 'neutral'

# %%
gray = cv2.cvtColor(img_test, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(gray,1.1,4)

for(x, y, w, h) in faces:
    cv2.rectangle(img_test, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img_test, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img_test,
               predictions['dominant_emotion'],
               (0,50),
               font, 1,
               (0, 0, 255),
               2,
               cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img_test, cv2.COLOR_BGR2RGB))

# %%
################################################################################################################################
